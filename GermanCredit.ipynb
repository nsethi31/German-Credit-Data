# %%
#importing packages
import pandas as pd
import numpy as np

#loading the data set
df=pd.read_csv("C:/Users/sethi/Desktop/GermanCredit.csv")

#viewing the data set
df.head
df.dtypes

#converting the following features to 'category' type
df["C_ACCOUNT"]=df["CHK_ACCT"].astype("category")
df['JOB_TYPE']=df['JOB'].astype('category')
df['RESIDENT']=df['PRESENT_RESIDENT'].astype('category')
df['EMPLOY']=df['EMPLOYMENT'].astype('category')
df['S_ACCOUNT']=df['SAV_ACCT'].astype('category')
df['CRED_HIST']=df['HISTORY'].astype('category')

#dropping the old features
df.drop(['CHK_ACCT','HISTORY','SAV_ACCT','PRESENT_RESIDENT','JOB','EMPLOYMENT'],axis=1,inplace=True)

#viewing the transformed data set
df.dtypes
df.columns
df.shape

#creating dummy variables for the categorical features
dummies=pd.get_dummies(df,columns=['C_ACCOUNT','JOB_TYPE','RESIDENT','EMPLOY','S_ACCOUNT','CRED_HIST'],drop_first=True)

#viewing the shape and columns of the data set 
dummies.shape
dummies.columns

#creating the target variable
target=dummies[['RESPONSE']]

#dropping the target variable from the data set
dummies.drop('RESPONSE',axis=1,inplace=True)

#creating the data as numpy array
data=np.array(dummies)
data.shape

#transforming the target into numpy array
target=np.array(target)
target.shape

#Using X as data and y as target
X=data
y=target

#viewing the shape of the data and target
X.shape
y.shape

#importing scikit learn packages
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score
from sklearn import metrics
from sklearn.preprocessing import binarize
import matplotlib.pyplot as plt

#first using train-test split (70:30)
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3)
print(X_train.shape)
print(y_test.shape)

print("Logistic Regression")
#Logistic Regression
logreg=LogisticRegression()
logreg.fit(X_train,y_train)
y_pred_logreg=logreg.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred_logreg))
#0.746666666667

print("knn")
#K Nearest Neighbors
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_pred_knn=knn.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred_knn))
#0.64

print("Random Forest")
#Random Forest
rfc=RandomForestClassifier(n_estimators=50,criterion='entropy')
rfc.fit(X_train,y_train)
y_pred_rfc=rfc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred_rfc))
print(rfc.feature_importances_)

rfc1=RandomForestClassifier(n_estimators=70,criterion='gini')
rfc1.fit(X_train,y_train)
y_pred_rfc1=rfc1.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred_rfc1))
print(rfc1.feature_importances_)

print("Ada Boosting")
#AdaBoosting
abc=AdaBoostClassifier(n_estimators=75)
abc.fit(X_train,y_train)
y_pred_abc=abc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred_abc))

print("Decision Tree")
#Decision Tree
dt=DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None)
dt.fit(X_train,y_train)
y_pred=dt.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
#0.646666666667

dt=DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=16, min_samples_split=4, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=2, max_leaf_nodes=None)
dt.fit(X_train,y_train)
y_pred=dt.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
#0.653333333333

dt=DecisionTreeClassifier(criterion='entropy', splitter='best', max_depth=16, min_samples_split=4, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=2, max_leaf_nodes=None)
dt.fit(X_train,y_train)
y_pred=dt.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
#0.636666666667

dt=DecisionTreeClassifier(criterion='entropy', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None)
dt.fit(X_train,y_train)
y_pred=dt.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
#0.65

dt=DecisionTreeClassifier(criterion='entropy', splitter='random', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None)
dt.fit(X_train,y_train)
y_pred=dt.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
#0.653333333333

dt=DecisionTreeClassifier(criterion='entropy', splitter='random', max_depth=20, min_samples_split=4, min_samples_leaf=3, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None)
dt.fit(X_train,y_train)
y_pred=dt.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
#0.656666666667

dt=DecisionTreeClassifier(criterion='entropy', splitter='random', max_depth=12, min_samples_split=4, min_samples_leaf=3, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None)
dt.fit(X_train,y_train)
y_pred=dt.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
#0.67

dt=DecisionTreeClassifier(criterion='entropy', splitter='random', max_depth=12, min_samples_split=4, min_samples_leaf=3, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=30)
dt.fit(X_train,y_train)
y_pred=dt.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
#0.676666666667

#Confusion Matrix and other metrics (Accuracy,Error Rate,Precision,Sensitivity (Recall),Specificity,False Positive Rate)
print(metrics.confusion_matrix(y_test,y_pred))
#[[ 45  37]
#[ 53 165]]

confusion=metrics.confusion_matrix(y_test,y_pred)

TP=confusion[1,1]
TN=confusion[0,0]
FP=confusion[0,1]
FN=confusion[1,0]

TP,TN,FP,FN
#(165, 45, 37, 53)

#Accuracy
print((TP+TN)/float(TP+TN+FP+FN))
print(metrics.accuracy_score(y_test,y_pred))
#0.7

#Error Rate
print((FP+FN)/float(TP+TN+FP+FN))
print(1-metrics.accuracy_score(y_test,y_pred))
#0.3

#Recall
print(TP/float(TP+FN))
print(metrics.recall_score(y_test,y_pred))
#0.756880733945

#Precision
print(TP/float(TP+FP))
print(metrics.precision_score(y_test,y_pred))
#0.816831683168

#Specificity
print(TN/float(TN+FP))
#0.548780487805

#False Positive Rate
print(FP/float(TN+FP))
#0.451219512195

#Predicted probability of test set
y_pred_prob=dt.predict_proba(X_test)[:,1]

#Plotting histogram of the predicted probabilities
plt.hist(y_pred_prob,bins=8)
plt.xlim(0,1)
plt.show()

#threshold=0.3 for predicted probabilities
y_pred1=binarize(y_pred_prob,0.3)[0]

print(metrics.confusion_matrix(y_test,y_pred1))
#[[ 18  64]
#[ 21 197]]

#Accuracy at threshold=0.3
print(metrics.accuracy_score(y_test,y_pred1))
#0.716666666667

#Precision at threshold=0.3
print(metrics.precision_score(y_test,y_pred1))
#0.754789272031

#Recall at threshold=0.3
print(metrics.recall_score(y_test,y_pred1))
#0.903669724771

#threshold=0.4 for predicted probabilities
y_pred2=binarize(y_pred_prob,0.4)[0]

print(metrics.confusion_matrix(y_test,y_pred2))
#[[ 45  37]
#[ 50 168]]

#Accuracy at threshold=0.3
print(metrics.accuracy_score(y_test,y_pred2))
#.71

#Precision at threshold=0.4
print(metrics.precision_score(y_test,y_pred2))
#0.819512195122

#Recall at threshold=0.4
print(metrics.recall_score(y_test,y_pred2))
#0.770642201835

#ROC Curve and AUC
#True Positive Rate, False Positive Rate and Thresholds
tpr,fpr,thresholds=metrics.roc_curve(y_test,y_pred_prob)

#Plotting the ROC curve
plt.plot(fpr,tpr)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

#Printing the ROC AUC score
print(metrics.roc_auc_score(y_test,y_pred_prob))
#0.685667934661

#Defining a function to find Sensitivity and Specificity at different thresholds
def evaluate_threshold(threshold):
    print('Sensitivity:',tpr[thresholds>threshold][-1])
    print('Specificity:',1-(fpr[thresholds>threshold])[-1])

#Threshold=0.3
evaluate_threshold(0.3)
#Sensitivity: 0.780487804878
#Specificity: 0.0963302752294

#Threshold=0.4
evaluate_threshold(0.4)
#Sensitivity: 0.451219512195
#Specificity: 0.229357798165

#Threshold=0.5
evaluate_threshold(0.5)
#Sensitivity: 0.451219512195
#Specificity: 0.243119266055
# Out:
# C:\Users\sethi\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# (700, 45)
# (300, 1)
# Logistic Regression
# 0.756666666667
# knn
# 0.626666666667
# Random Forest
# C:\Users\sethi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sethi\Anaconda3\lib\site-packages\ipykernel\__main__.py:85: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# C:\Users\sethi\Anaconda3\lib\site-packages\ipykernel\__main__.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\sethi\Anaconda3\lib\site-packages\ipykernel\__main__.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.716666666667
# [ 0.09658027  0.01868149  0.01251495  0.01376157  0.01921384  0.01214027
#   0.01176261  0.11089758  0.04141345  0.00631211  0.02124005  0.01127616
#   0.0068006   0.00908588  0.02150148  0.0168435   0.08841637  0.02165145
#   0.01019595  0.01581137  0.02383947  0.01180099  0.01973201  0.00691401
#   0.01902686  0.01038825  0.0685448   0.01233052  0.01722432  0.01345762
#   0.01845788  0.0125617   0.01724256  0.0168394   0.01765534  0.01323374
#   0.01990516  0.014442    0.00803037  0.01036424  0.01892097  0.01555755
#   0.01491216  0.00982744  0.02268969]
# 0.713333333333
# [ 0.0937982   0.02203688  0.01170937  0.01473221  0.01499946  0.01263226
#   0.01157488  0.11844264  0.03928677  0.00860848  0.02106883  0.00920481
#   0.00740957  0.00798485  0.01530817  0.01411868  0.09753191  0.02563437
#   0.01343054  0.01833733  0.02042694  0.01467347  0.02152978  0.00307458
#   0.02023886  0.01067195  0.06668889  0.01545922  0.01595696  0.01197206
#   0.01680695  0.01292406  0.01657952  0.02036439  0.0176494   0.01283048
#   0.01572988  0.01224839  0.00734439  0.00781531  0.0170861   0.01938322
#   0.016257    0.0078347   0.02060328]
# Ada Boosting
# C:\Users\sethi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.723333333333
# Decision Tree
# 0.683333333333
# 0.67
# 0.66
# 0.676666666667
# 0.653333333333
# 0.65
# 0.676666666667
# 0.706666666667
# [[ 41  56]
#  [ 32 171]]
# 0.706666666667
# 0.706666666667
# 0.293333333333
# 0.293333333333
# 0.84236453202
# 0.84236453202
# 0.753303964758
# 0.753303964758
# 0.422680412371
# 0.577319587629
# [[ 17  80]
#  [ 12 191]]
# 0.693333333333
# 0.70479704797
# 0.940886699507
# [[ 17  80]
#  [ 12 191]]
# 0.693333333333
# 0.70479704797
# 0.940886699507
# C:\Users\sethi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\sethi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# 0.734853486364
# Sensitivity: 0.824742268041
# Specificity: 0.0591133004926
# Sensitivity: 0.824742268041
# Specificity: 0.0591133004926
# Sensitivity: 0.577319587629
# Specificity: 0.15763546798
